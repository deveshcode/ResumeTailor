# %% [markdown]
# # Tree of Thought to tailor work exp and skills

# %%
import os
import openai
from openai import OpenAI
work_experience="""Massachusetts General Hospital June 2023 – December 2023
Data Scientist Co-op Cambridge, Massachusetts
- Preprocessed clinical notes using MedSpacy and finetuned Bio-ClinicalBERT for multi-label sequence classification of
Dementia symptoms
- Implemented K-Means Clustering to group longitudinal cohort based on dementia progression and demographics, increasing plan efficiency by 15%
- Utilized Wilcoxon statistical tests and Lasso Logistic Regression to predict diagnosis of dementia diseases and generated key insights using SHAP Plots

HSBC Technology India September 2020 – June 2022
Software Engineer Pune, India
- Employed LightGBM using predictive modelling and feature engineering to classify financial risk pools among credit customers, resulting in 15% potential risk reduction
- Analyzed credit risk data using SQL and PySpark queries and developed insights on Tableau dashboards using real-time transactions data leading to a 20% increase in marketing conversion rates
- Utilized BERT and GLOVE embeddings to enhance paraphrase detection capabilities, achieving model fine-tuning with accuracy improvements from 75% to 93%"""

jobDescription="""
Responsibilities

Develop highly scalable tools leveraging machine learning models to solve problems such as classification, clustering, topic modeling, natural language processing and recommendation
Develop in-house machine learning tools and pipelines to support fast experimentation of machine learning models
Work with other engineers to identify and solve machine learning problems

Requirements

Experience in one or more of the following areas: machine learning, recommendation systems, deep learning, feed, relevance and data mining.
Expert knowledge in Java or Scala
Experience with scripting languages such as Perl, Python, and shell scripts
MS degree in Computer Science or related quantitative field
Experience with machine learning frameworks such as TensorFlow, PyTorch or MxNet"""


# prompt = f"Tailor my Experience {work_experience} to this job description: {jobDescription}\n\n"
 # Formulate the prompt using a tree-of-thought approach
prompt = (f"Consider this work experience listed here:\n{work_experience}\n\n"
              "And this job description:\n{job_description}\n\n"
              "Step 1: Identify key skills and technologies in the job description.\n"
              "Step 2: Match these skills and technologies with the relevant experiences listed in the work experience .\n"
              "Step 3: Draft a tailored version of the work experience  that highlights the matches and aligns with the job requirements.\n"
              "Result:")

OPENAI_API_KEY="sk-proj-iln3f0dtJlGWEzwAxFN5T3BlbkFJc5zjqu731t7pGTi5uYvQ"
    
if not OPENAI_API_KEY:
    raise ValueError("OpenAI API key not found. Please set the OPENAI_API_KEY environment variable.")

try:
    client = OpenAI(
    api_key= OPENAI_API_KEY,) 
    chat_completion = client.chat.completions.create(
        messages=[
                {
                    "role": "user",
                    "content": prompt,
                }
            ],
            model="gpt-3.5-turbo",
        )
    response=chat_completion.choices[0].message.content
    print(response)
except Exception as e:
    raise HTTPException(status_code=500, detail=f"OpenAI API error: {str(e)}")
# Out:
# Key skills and technologies in the job description:
# - Data preprocessing using MedSpacy and BERT
# - Machine learning techniques such as K-Means Clustering, Wilcoxon statistical tests, and Logistic Regression
# - Data visualization tools like Tableau
# - Predictive modeling with LightGBM
# - Feature engineering
# - SQL and PySpark queries
# - Natural language processing (BERT and GLOVE embeddings)
#
# Tailored work experience:
#
# Massachusetts General Hospital June 2023 – December 2023
# Data Scientist Co-op Cambridge, Massachusetts
# - Demonstrated proficiency in data preprocessing techniques using MedSpacy and Bio-ClinicalBERT, successfully fine-tuning them for efficient multi-label sequence classification of Dementia symptoms
# - Implemented advanced machine learning techniques such as K-Means Clustering to group longitudinal cohort based on dementia progression and demographics, resulting in a 15% increase in plan efficiency
# ...

# %% [markdown]
# # SKILLS

# %%
import os
import openai
from openai import OpenAI

skills="""Programming Languages: Python (SpaCy, NLTK, Scikit-learn, PyTorch, Keras, TensorFlow, Pandas), SQL, Python, R,
SAS, Excel (Power Query, VBA)
Tools and Frameworks: Tableau, BigQuery, Snowflake, Spark, MS Excel, Jupyter
Databases and Cloud: MySQL, MongoDB, AWS , Snowflake)
Machine Learning: Regression, Classification, Clustering, Machine Vision, Deep Learning, Statistical modeling"""

jobDescription="""
Responsibilities

Develop highly scalable tools leveraging machine learning models to solve problems such as classification, clustering, topic modeling, natural language processing and recommendation
Develop in-house machine learning tools and pipelines to support fast experimentation of machine learning models
Work with other engineers to identify and solve machine learning problems

Requirements

Experience in one or more of the following areas: machine learning, recommendation systems, deep learning, feed, relevance and data mining.
Expert knowledge in Java or Scala
Experience with scripting languages such as Perl, Python, and shell scripts
MS degree in Computer Science or related quantitative field
Experience with machine learning frameworks such as TensorFlow, PyTorch or MxNet"""


# prompt = f"Tailor my Experience {work_experience} to this job description: {jobDescription}\n\n"
 # Formulate the prompt using a tree-of-thought approach
prompt = (f"Consider these skills listed from  job description here:\n{jobDescription}\n\n"
              "And these resume skills :\n{skills}\n\n"
              "Step 1: Identify key skills , keywords and technologies from the job description \n"
            "Step 2: Identify new skills for resume which align with job description \n"
              "Result:")

OPENAI_API_KEY="sk-proj-iln3f0dtJlGWEzwAxFN5T3BlbkFJc5zjqu731t7pGTi5uYvQ"
    
if not OPENAI_API_KEY:
    raise ValueError("OpenAI API key not found. Please set the OPENAI_API_KEY environment variable.")

try:
    client = OpenAI(
    api_key= OPENAI_API_KEY,) 
    chat_completion = client.chat.completions.create(
        messages=[
                {
                    "role": "user",
                    "content": prompt,
                }
            ],
            model="gpt-3.5-turbo",
        )
    response=chat_completion.choices[0].message.content
    print(response)
except Exception as e:
    raise HTTPException(status_code=500, detail=f"OpenAI API error: {str(e)}")
# Out:
# Key skills, keywords, and technologies from the job description:
# - Machine learning models
# - Classification
# - Clustering
# - Topic modeling
# - Natural language processing
# - Recommendation systems
# - Java
# - Scala
# - Scripting languages (Perl, Python, shell scripts)
# - MS degree in Computer Science or related quantitative field
# - Machine learning frameworks (TensorFlow, PyTorch, MxNet)
#
# New skills to add to the resume based on job description:
# - Development of highly scalable tools leveraging machine learning models
# - Development of in-house machine learning tools and pipelines
# - Problem-solving skills in machine learning
# - Expertise in recommendation systems and data mining
# - Experience with deep learning and relevance
# - Knowledge of machine learning frameworks such as TensorFlow, PyTorch, MxNet
